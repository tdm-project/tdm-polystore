# %% [markdown]
# # Experiments with postgis

# %% [markdown]
# Here the goal is to check if we can use postgis as our geometrical/geographical indexing engine

# %%
import psycopg2 as psy
import pandas as pd

# %%
from osgeo import ogr
from osgeo import osr

source = osr.SpatialReference()
source.ImportFromEPSG(4326)

target = osr.SpatialReference()
target.ImportFromEPSG(3003)

transform = osr.CoordinateTransformation(source, target)

def map_to_monte_mario(wkt):
    geom = ogr.CreateGeometryFromWkt(wkt)
    geom.Transform(transform)
    return geom.ExportToWkt()

print(map_to_monte_mario('POINT(9.1092760 39.2284606)'))
POLY = "POLYGON ((9.147340 39.239940, 9.147380 39.239940, 9.147380 39.239960, 9.147340 39.239980, 9.147340 39.239940))"
print(map_to_monte_mario(POLY))
# Out:
# POINT (1509456.93227705 4342142.10053815)
# POLYGON ((1512740.33316648 4343420.69829172,1512743.78517678 4343420.70389382,1512743.78157428 4343422.92345131,1512740.32596343 4343425.1374067,1512740.33316648 4343420.69829172))

# %%
# create testdb
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT
con = psy.connect("dbname=postgres host=localhost user=postgres password=foobar")

with con:
    con.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)
    with con.cursor() as cur:
        cur.execute("DROP DATABASE IF EXISTS testdbgis;")
        cur.execute("CREATE DATABASE testdbgis;")

# %%
con = psy.connect("dbname=testdbgis host=localhost user=postgres password=foobar")

with con:
    with con.cursor() as cur:   
        cur.execute("CREATE EXTENSION IF NOT EXISTS postgis;")
        cur.execute("SELECT postgis_version();")
        print(cur.fetchall())
        cur.execute("SELECT srid, auth_name, proj4text FROM spatial_ref_sys LIMIT 3;")
        for x in cur.fetchall():
            print(x)
        cur.execute("SELECT srid, auth_name, proj4text FROM spatial_ref_sys WHERE srid = 3003")
        print(cur.fetchall())
con.close()
# Out:
# [('2.5 USE_GEOS=1 USE_PROJ=1 USE_STATS=1',)]
# (3819, 'EPSG', '+proj=longlat +ellps=bessel +towgs84=595.48,121.69,515.35,4.115,-2.9383,0.853,-3.408 +no_defs ')
# (3821, 'EPSG', '+proj=longlat +ellps=aust_SA +no_defs ')
# (3824, 'EPSG', '+proj=longlat +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +no_defs ')
# [(3003, 'EPSG', '+proj=tmerc +lat_0=0 +lon_0=9 +k=0.9996 +x_0=1500000 +y_0=0 +ellps=intl +towgs84=-104.1,-49.1,-9.9,0.971,-2.917,0.714,-11.68 +units=m +no_defs ')]

# %% [markdown]
# ## Saving point-probes location
#
# Simplest scenario, we are just saving sensors positions.

# %%
sensors = pd.read_csv('./data/sensor_data_denorm.csv', index_col='id')

# %%
sensors.head(n=2)
# Out:
#    name                                          note  station_id  \
# id
# 1    S1  Viale Marconi ingresso Viale Marconi ingr dx           1
# 2    S2  Viale Marconi ingresso Viale Marconi ingr sx           1
#
#     sensor_type   latitude  longitude station_name
# id
# 1             4  39.239953   9.147368    MARCONI_I
# 2             4  39.239953   9.147368    MARCONI_I

# %%
con = psy.connect("dbname=testdbgis host=localhost user=postgres password=foobar")

with con:
    with con.cursor() as cur:
        cur.execute("""
            DROP TABLE IF EXISTS sensors;
            CREATE TABLE sensors (
              id int4 primary key,
              name VARCHAR(20),
              note VARCHAR(100),
              station_id int4,
              sensor_type int4,
              geom geometry(POINT,3003) );
        """)
con.close()

# %%
SQL = """INSERT INTO sensors (id, name, note, station_id, sensor_type, geom)
         VALUES (%s, %s, %s, %s, %s, ST_GeomFromText(%s, 3003));"""

con = psy.connect("dbname=testdbgis host=localhost user=postgres password=foobar")
with con:
    with con.cursor() as cur:
        for i, v in zip(sensors.index, sensors.values):
            (name, note, st_id, stype, lat, lon) = v[:-1]
            cur.execute(SQL, (i, name, 
                              note, st_id, stype, 
                              map_to_monte_mario("POINT (%s %s)" % (lon, lat))))
con.close()
# Out:
# ['S1' 'Viale Marconi ingresso Viale Marconi ingr dx' 1 4
#  39.239952771999995 9.14736801385 'MARCONI_I']
# POINT (1512742.74846858 4343422.11962438)
# ['S2' 'Viale Marconi ingresso Viale Marconi ingr sx' 1 4
#  39.239952771999995 9.14736801385 'MARCONI_I']
# POINT (1512742.74846858 4343422.11962438)
# ['S3' 'Viale Marconi uscita Viale Marconi uscita dx' 2 4 39.2399100739
#  9.14742141869 'MARCONI_U']
# POINT (1512747.36501236 4343417.38856126)
# ['S4' 'Viale Marconi uscita Viale Marconi uscita sx' 2 4 39.2399100739
#  9.14742141869 'MARCONI_U']
# POINT (1512747.36501236 4343417.38856126)
# ['S5'
#  'Circonvallazione Pirri - Via Quasimodo IN Circonvallazione Pirri - Via Quasimodo'
#  3 4 39.2531666371 9.11308806904 'PIRRI_I']
# POINT (1509782.55615189 4344884.32612236)
# ['S6'
#  'Circonvallazione Pirri - Via Quasimodo IN Circonvallazione Pirri - Via Quasimodo'
#  3 4 39.2531666371 9.11308806904 'PIRRI_I']
# POINT (1509782.55615189 4344884.32612236)
# ['S7'
#  'Circonvallazione Pirri - Via Quasimodo OUT Circonvallazione Pirri - Via Quasimodo'
#  4 4 39.2531847009 9.11319092524 'PIRRI_U']
# POINT (1509791.42850112 4344886.34186115)
# ['S8'
#  'Circonvallazione Pirri - Via Quasimodo OUT Circonvallazione Pirri - Via Quasimodo'
#  4 4 39.2531847009 9.11319092524 'PIRRI_U']
# POINT (1509791.42850112 4344886.34186115)
# ['S9' 'Viale Monastir IN SS 131 Ingresso dx' 5 4 39.2573849327
#  9.08907706359 'MONASTIR_I']
# POINT (1507710.33147094 4345350.1603386)
# ['S10' 'Viale Monastir IN SS 131 Ingresso sx' 5 4 39.2573849327
#  9.08907706359 'MONASTIR_I']
# POINT (1507710.33147094 4345350.1603386)
# ['S11' 'Viale Monastir OUT SS131 Uscita sx' 6 4 39.2574054688 9.0891398738
#  'MONASTIR_U']
# POINT (1507715.74842868 4345352.44470849)
# ['S12' 'Viale Monastir OUT SS131 Uscita dx' 6 4 39.2574054688 9.0891398738
#  'MONASTIR_U']
# POINT (1507715.74842868 4345352.44470849)
# ['S13' 'Viale Elmas SS 130 Civ 154 IN Viale Elmas SS 130 Civ 154' 7 4
#  39.2483116151 9.0861730106 'ELMAS_I']
# POINT (1507460.72729455 4344342.97958354)
# ['S14' 'Viale Elmas SS 130 Civ 154 IN Viale Elmas SS 130 Civ 154' 7 4
#  39.2483116151 9.0861730106 'ELMAS_I']
# POINT (1507460.72729455 4344342.97958354)
# ['S15' 'Viale Elmas SS 130 Civ 154 OUT Viale Elmas SS 130 Civ 154' 8 4
#  39.248337441 9.086233595680001 'ELMAS_U']
# POINT (1507465.95246125 4344345.85064497)
# ['S16' 'Viale Elmas SS 130 Civ 154 OUT Viale Elmas SS 130 Civ 154' 8 4
#  39.248337441 9.086233595680001 'ELMAS_U']
# POINT (1507465.95246125 4344345.85064497)
# ['S17' 'Direzione Cagliari SS 195 Raccordo' 9 4 39.2421944445
#  9.08645277742 'SS195 Raccordo_I']
# POINT (1507485.51363714 4343664.13158336)
# ['S18' 'Direzione Cagliari SS 195 Raccordo' 9 4 39.2421944445
#  9.08645277742 'SS195 Raccordo_I']
# POINT (1507485.51363714 4343664.13158336)
# ['S19' 'Direzione Elmas SS 195 Raccordo' 10 4 39.2422250001 9.08655555547
#  'SS195 Raccordo_U']
# POINT (1507494.37989471 4343667.53101375)
# ['S20' 'Direzione Elmas SS 195 Raccordo' 10 4 39.2422250001 9.08655555547
#  'SS195 Raccordo_U']
# POINT (1507494.37989471 4343667.53101375)
# ['S21' 'SS 195 Distributore AGIP IN SS 195 Distributore AGIP' 11 4
#  39.224613888899995 9.06482222214 'AGIP_I']
# POINT (1505620.23996956 4341711.53088223)
# ['S22' 'SS 195 Distributore AGIP IN SS 195 Distributore AGIP' 11 4
#  39.224613888899995 9.06482222214 'AGIP_I']
# POINT (1505620.23996956 4341711.53088223)
# ['S23' 'SS 195 Distributore AGIP OUT SS 195 Distributore AGIP' 12 4
#  39.224705555599996 9.064797222020001 'AGIP_U']
# POINT (1505618.07475075 4341721.70229067)
# ['S24' 'SS 195 Distributore AGIP OUT SS 195 Distributore AGIP' 12 4
#  39.224705555599996 9.064797222020001 'AGIP_U']
# POINT (1505618.07475075 4341721.70229067)
# ['S25' 'Viale Italia ingr Viale Italia  > CA dx' 13 4 39.2517869688
#  9.13463004864 'ITALIA_I']
# POINT (1511641.5120396 4344733.74803998)
# ['S26' 'Viale Italia ingr Viale Italia  > CA sx' 13 4 39.2517869688
#  9.13463004864 'ITALIA_I']
# POINT (1511641.5120396 4344733.74803998)
# ['S27' 'Via Vesalio Ingresso Via Vesalio' 15 4 39.240976632 9.13529464834
#  'VESALIO_I']
# POINT (1511700.64489522 4343534.12387561)
# ['S28' 'Via Vesalio Ingresso Via Vesalio' 15 4 39.240976632 9.13529464834
#  'VESALIO_I']
# POINT (1511700.64489522 4343534.12387561)
# ['S29' 'Asse mediano -> Amsicora Asse mediano' 17 4 39.224868150300004
#  9.13825796589 'MEDIANO_I']
# POINT (1511959.09726201 4341746.82626247)
# ['S30' 'Asse mediano -> Amsicora Asse mediano' 17 4 39.224868150300004
#  9.13825796589 'MEDIANO_I']
# POINT (1511959.09726201 4341746.82626247)
# ['S31' 'Asse mediano - > Pirri Asse mediano' 18 4 39.224891776
#  9.13836453662 'MEDIANO_U']
# POINT (1511968.29231713 4341749.46219058)
# ['S32' 'Asse mediano - > Pirri Asse mediano' 18 4 39.224891776
#  9.13836453662 'MEDIANO_U']
# POINT (1511968.29231713 4341749.46219058)
# ['S33' 'Via Vesalio Uscita Via Vesalio' 16 4 39.2409041402 9.13536134017
#  'VESALIO_U']
# POINT (1511706.41232236 4343526.08746507)
# ['S34' 'Via Vesalio Uscita Via Vesalio' 16 4 39.2409041402 9.13536134017
#  'VESALIO_U']
# POINT (1511706.41232236 4343526.08746507)
# ['S35' 'Viale Italia uscita Viale Italia  > Monserrato dx' 14 4
#  39.2517489338 9.1346959221 'ITALIA_U']
# POINT (1511647.20224077 4344729.53541795)
# ['S36' 'Viale Italia uscita Viale Italia  > Monserrato sx' 14 4
#  39.2517489338 9.1346959221 'ITALIA_U']
# POINT (1511647.20224077 4344729.53541795)
# ['S37' 'via Torricelli > via Vesalio via Torricelli > Vesalio Dx' 20 4
#  39.236798268200005 9.13031983579 'TORRICELLI_U']
# POINT (1511271.98893528 4343069.79033646)
# ['S38' 'via Torricelli > via Vesalio via Torricelli > Vesalio Sx' 20 4
#  39.236798268200005 9.13031983579 'TORRICELLI_U']
# POINT (1511271.98893528 4343069.79033646)
# ['S39' 'via Torricelli  > via Chiabrera via Torricelli > Chiabrera Sx' 19
#  4 39.2368300709 9.13021954967 'TORRICELLI_I']
# POINT (1511263.32877309 4343073.30731808)
# ['S40' 'via Torricelli  > via Chiabrera via Torricelli > Chiabrera Dx' 19
#  4 39.2368300709 9.13021954967 'TORRICELLI_I']
# POINT (1511263.32877309 4343073.30731808)
# ['S41' 'Via Dante > Piazza Giovanni Via Dante > Piazza Giovanni dx' 21 4
#  39.2218694444 9.12511388851 'VIA DANTE']
# POINT (1510824.97562787 4341412.39288423)
# ['S42' 'Via Dante > Piazza Giovanni Via Dante > Piazza Giovanni sx' 21 4
#  39.2218694444 9.12511388851 'VIA DANTE']
# POINT (1510824.97562787 4341412.39288423)
# ['S43' 'Via Scano > Piazza Amsicora Via Scano > Piazza Amsicora dx' 22 4
#  39.2150023557 9.130238637969999 'SCANO DIR AMSICORA']
# POINT (1511268.44839854 4340650.92244882)
# ['S44' 'Via Scano > Piazza Amsicora Via Scano > Piazza Amsicora sx' 22 4
#  39.2150023557 9.130238637969999 'SCANO DIR AMSICORA']
# POINT (1511268.44839854 4340650.92244882)
# ['S45' 'Via Scano > Piazza Repubblica Via Scano > Piazza Repubblica sx' 23
#  4 39.2150032737 9.130354962610001 'SCANO DIR REPUBBLICA']
# POINT (1511278.4906507 4340651.03872382)
# ['s46' 'Via Scano > Piazza Repubblica Via Scano > Piazza Repubblica dx' 23
#  4 39.2150032737 9.130354962610001 'SCANO DIR REPUBBLICA']
# POINT (1511278.4906507 4340651.03872382)
# ['S47' 'Via Sonnino > via Roma via Sonnino > via Roma Dx' 24 4
#  39.218376929899996 9.1216800442 'SONNINO']
# POINT (1510529.07691569 4341024.39998965)
# ['S48' 'Via Sonnino > via Roma via Sonnino > via Roma Sx' 24 4
#  39.218376929899996 9.1216800442 'SONNINO']
# POINT (1510529.07691569 4341024.39998965)
# ['S49' 'vle S.Avendrace > vle Trieste vle S.Avendrace > vle Trieste' 25 4
#  39.2335164318 9.097407346039999 'AVENDRACE DIR TRIESTE']
# POINT (1508431.89681659 4342702.0205699)
# ['S50' 'vle S.avendrace > via S.Michele vle S.Avendrace > via S.Michele'
#  26 4 39.2335222223 9.09746944478 'AVENDRACE DIR S.MICHELE']
# POINT (1508437.25575173 4342702.66892939)
# ['S51'
#  'Via dei Giudicati  > Via Bacaredda via Giudicati > via Bacaredda Dx' 27
#  4 39.2286574373 9.12039292279 'GIUDICATI']
# POINT (1510416.45272819 4342165.15740921)
# ['S52'
#  'Via dei Giudicati  > Via Bacaredda via Giudicati > via Bacaredda centro Dx'
#  27 4 39.2286574373 9.12039292279 'GIUDICATI']
# POINT (1510416.45272819 4342165.15740921)
# ['S53'
#  'Via dei Giudicati  > Via Bacaredda via Giudicati > via Bacaredda centro Sx'
#  27 4 39.2286574373 9.12039292279 'GIUDICATI']
# POINT (1510416.45272819 4342165.15740921)
# ['S54'
#  'Via dei Giudicati  > Via Bacaredda via Giudicati > via Bacaredda Sx' 27
#  4 39.2286574373 9.12039292279 'GIUDICATI']
# POINT (1510416.45272819 4342165.15740921)
# ['S55' 'Via Santa Maria Chiara > Cagliari Santa Maria Chiara > Cagliari'
#  28 4 39.241627778099996 9.12139444462 'SANTA MARIA CHIARA IN']
# POINT (1510500.97502321 4343604.6917604)
# ['S56' 'Via Santa Maria chiara > Pirri Via Santa Maria Chiara > Pirri' 29
#  4 39.2416194446 9.121430556 'SANTA MARIA CHIARA OUT']
# POINT (1510504.09260541 4343603.77109098)
# ['S57' 'Marconi Mediano > Quartu Viale Marconi > Quartu dx' 31 4
#  39.2312494778 9.13450618085 'MARCONI-MED OUT']
# POINT (1511634.19949471 4342454.52474529)
# ['S58' 'Marconi Mediano > Quartu Viale Marconi > Quartu sx' 31 4
#  39.2312494778 9.13450618085 'MARCONI-MED OUT']
# POINT (1511634.19949471 4342454.52474529)
# ['S59' 'Marconi Mediano > cagliari Viale Marconi > Cagliari sx' 30 4
#  39.2312735927 9.134457582889999 'MARCONI-MED IN']
# POINT (1511630.00100014 4342457.19475177)
# ['S60' 'Marconi Mediano > cagliari Viale Marconi > Cagliari dx' 30 4
#  39.2312735927 9.134457582889999 'MARCONI-MED IN']
# POINT (1511630.00100014 4342457.19475177)
# ['S61' 'Ciusa > Bacaredda Ciusa > Bacaredda dx' 32 4 39.2319164309
#  9.121461061889999 'CIUSA IN']
# POINT (1510508.16472319 4342526.9555963)
# ['S62' 'Ciusa > Bacaredda Ciusa > Bacaredda sx' 32 4 39.2319164309
#  9.121461061889999 'CIUSA IN']
# POINT (1510508.16472319 4342526.9555963)
# ['S63' 'Ciusa > Pirri Ciusa > Pirri' 33 4 39.231878588200004 9.1215275498
#  'CIUSA OUT']
# POINT (1510513.90891605 4342522.76357338)
# ['S64' 'Bacaredda > Sonnino Bacaredda > Sonnino dx' 34 4 39.2257969209
#  9.120572688260001 'BACAREDDA']
# POINT (1510432.39019478 4341847.72471623)
# ['S65' 'Bacaredda > Sonnino Bacaredda > Sonnino sx' 34 4 39.2257969209
#  9.120572688260001 'BACAREDDA']
# POINT (1510432.39019478 4341847.72471623)
# ['S66' 'Via Italia > Monserrato Via Italia > Monserrato' 35 4
#  39.2511210888 9.13405042418 'ITALIA-PISANO OUT']
# POINT (1511591.60781318 4344659.77596159)
# ['S67' 'VIa Italia > Cagliari Via Italia > Cagliari' 36 4
#  39.251153278800004 9.133985576599999 'ITALIA-PISANO IN']
# POINT (1511586.00706826 4344663.34008746)
# ['S68' 'Via Po > avendrace Via Po > Avendrace dx' 37 4 39.2329149573
#  9.095747262989999 'PO DIR. AVENDRACE']
# POINT (1508288.6884909 4342635.11814451)
# ['S69' 'Via Po > avendrace Via Po > avendrace sx' 37 4 39.2329149573
#  9.095747262989999 'PO DIR. AVENDRACE']
# POINT (1508288.6884909 4342635.11814451)
# ['S70' 'Via Po > Brenta Via Po > Brenta sx' 38 4 39.232989917
#  9.09568070411 'PO DIR. BRENTA']
# POINT (1508282.93511929 4342643.43095326)
# ['S71' 'Via Po > Brenta Via Po > Brenta dx' 38 4 39.232989917
#  9.09568070411 'PO DIR. BRENTA']
# POINT (1508282.93511929 4342643.43095326)
# ['S72' 'Via Dei Valenzani > Viale Ciusa Via Dei Valenzani dx' 39 4
#  39.2321184872 9.12058304494 'VALENZANI']
# POINT (1510432.35326361 4342549.27841055)
# ['S73' 'Via Dei Valenzani > Viale Ciusa Via Dei Valenzani sx' 39 4
#  39.2321184872 9.12058304494 'VALENZANI']
# POINT (1510432.35326361 4342549.27841055)
# ['S74' 'Via Peretti > Brotzu Peretti > Brotzu dx' 41 4 39.2518931631
#  9.101904224319998 'PERETTI DIR BROTZU']
# POINT (1508817.72751512 4344741.85678331)
# ['S75' 'Via Peretti > Brotzu Peretti > Brotzu sx' 41 4 39.2518931631
#  9.101904224319998 'PERETTI DIR BROTZU']
# POINT (1508817.72751512 4344741.85678331)
# ['S76' 'VIa Peretti > SS131 Peretti > SS131' 40 4 39.2519972223
#  9.10192499965 'PERETTI DIR SS 131']
# POINT (1508819.50717497 4344753.40708216)
# ['S77' 'Riva di Ponente > Roma Riva di Ponente > Roma Dx' 44 4
#  39.2148253338 9.101733742939999 'RIVA DI PONENTE_IN']
# POINT (1508807.620478 4340628.13751068)
# ['S78' 'Riva di Ponente > Roma Riva di Ponente > Roma Sx' 44 4
#  39.2148253338 9.101733742939999 'RIVA DI PONENTE_IN']
# POINT (1508807.620478 4340628.13751068)
# ['S79' 'Riva di Ponente  > SS195 Riva di Ponente > SS195 Sx' 45 4
#  39.2148957597 9.10177538524 'RIVA DI PONENTE_OUT']
# POINT (1508811.2067535 4340635.95721278)
# ['S80' 'Riva di Ponente  > SS195 Riva di Ponente > SS195 Dx' 45 4
#  39.2148957597 9.10177538524 'RIVA DI PONENTE_OUT']
# POINT (1508811.2067535 4340635.95721278)
# ['S81' 'Mediano/P.Vittorio > Ferrara Mediano/P.Vittorio > Ferrara Dx' 46 4
#  39.203149999699995 9.14017777794 'A.MEDIANO/ P.VITTORIO _IN']
# POINT (1512128.53121789 4339336.85693504)
# ['S82' 'Mediano/P.Vittorio > Ferrara Mediano/P.Vittorio > Ferrara Sx' 46 4
#  39.203149999699995 9.14017777794 'A.MEDIANO/ P.VITTORIO _IN']
# POINT (1512128.53121789 4339336.85693504)
# ['S83'
#  'Mediano/P.Vittorio > Tramontana Mediano/P.Vittorio > Tramontana Sx' 47 4
#  39.2030722223 9.14023333335 'A.MEDIANO /P.VITTORIO_OUT']
# POINT (1512133.34148508 4339328.23281975)
# ['S84'
#  'Mediano/P.Vittorio > Tramontana Mediano /P.Vittorio >Tramontana Dx' 47 4
#  39.2030722223 9.14023333335 'A.MEDIANO /P.VITTORIO_OUT']
# POINT (1512133.34148508 4339328.23281975)
# ['S85' 'Mediano/Tramontana > Ferrara Mediano/Tramontana >Ferrara Dx' 48 4
#  39.205968329 9.14331920176 'MEDIANO/TRAMONTANA_IN']
# POINT (1512399.285188 4339650.05027006)
# ['S86' 'Mediano/Tramontana > Ferrara Mediano/Tramontana > Ferrara Sx' 48 4
#  39.205968329 9.14331920176 'MEDIANO/TRAMONTANA_IN']
# POINT (1512399.285188 4339650.05027006)
# ['S87' 'Mediano/Tramont > Conversi Mediano/Tramontana > Conversi Sx' 49 4
#  39.2059669723 9.14341911508 'MEDIANO/TRAMONTANA_OUT']
# POINT (1512407.91212784 4339649.9133171)
# ['S88' 'Mediano/Tramont > Conversi Mediano/Tramontana > Conversi Dx' 49 4
#  39.2059669723 9.14341911508 'MEDIANO/TRAMONTANA_OUT']
# POINT (1512407.91212784 4339649.9133171)
# ['S90' 'Tramontana >Asse Mediano Mediano/Tramontana >Immissione' 50 4
#  39.2058749999 9.14348888902 'MEDIANO/TRAMONT_Immissione']
# POINT (1512413.95265615 4339639.71598574)
# ['S91' 'Viale Colombo > Poetto Colombo > Poetto Dx' 42 4 39.2074769921
#  9.12250969137 'COLOMBO DIR POETTO']
# POINT (1510602.32783106 4339814.85014319)
# ['S92' 'Viale Colombo > Poetto Colombo > Poetto Sx' 42 4 39.2074769921
#  9.12250969137 'COLOMBO DIR POETTO']
# POINT (1510602.32783106 4339814.85014319)
# ['S93' 'Viale Colombo > Via Roma Colombo > Roma Sx' 43 4
#  39.207592589099995 9.12260107159 'COLOMBO DIR ROMA']
# POINT (1510610.20029917 4339827.6894142)
# ['S94' 'Viale Colombo > Via Roma Colombo > Roma Dx' 43 4
#  39.207592589099995 9.12260107159 'COLOMBO DIR ROMA']
# POINT (1510610.20029917 4339827.6894142)
# ['S97' 'via Stamira > Asse Mediano via Stamira > Asse Mediano' 53 4
#  39.2493713505 9.11591706073 'STAMIRA_OUT']
# POINT (1510027.19039418 4344463.44024085)
# ['S98' 'via Stamira > via Balilla via Stamira > via Balilla' 54 4
#  39.249313 9.115741 'STAMIRA_IN']
# POINT (1510012.00659649 4344456.9452479)
# ['S99' 'Mediano/Valenz Ingresso Mediano/Valenz Ingresso Dx' 55 4
#  39.2373005858 9.12010045504 'MEDIANO/VALENZANI_IN']
# POINT (1510389.94088475 4343124.32088829)
# ['S100' 'Mediano/Valenz Ingresso Mediano/Valenz Ingresso Sx' 55 4
#  39.2373005858 9.12010045504 'MEDIANO/VALENZANI_IN']
# POINT (1510389.94088475 4343124.32088829)
# ['S101' 'Mediano/Valenz Uscita Mediano/Valenz Uscita Sx' 56 4 39.237029
#  9.120459 'MEDIANO/VALENZANI_OUT']
# POINT (1510420.92451845 4343094.22185774)
# ['S102' 'Mediano/Valenz Uscita Mediano/Valenz Uscita Dx' 56 4 39.237029
#  9.120459 'MEDIANO/VALENZANI_OUT']
# POINT (1510420.92451845 4343094.22185774)
# ['S103' 'Via S.benedetto -> genneruxi San Benedetto > Genneruxi' 78 4
#  39.2248790191 9.12913553031 'SAN BENEDETTO DIR GENNERUXI']
# POINT (1511171.65866452 4341746.8737218)
# ['S104' 'Via San Benedetto -> Ariosto San Benedetto > Ariosto' 79 4
#  39.2248576349 9.12919073902 'SAN BENEDETTO DIR ARIOSTO']
# POINT (1511176.42758246 4341744.50732943)
# ['S105' 'Via Berlino -> Abbazia Berlino > Abbazia DX' 64 4 39.2239470501
#  9.136407498919999 'BERLINO DIR ABBAZIA']
# POINT (1511799.5208113 4341644.36334661)
# ['S106' 'Via Berlino -> Abbazia Berlino > Abbazia SX' 64 4 39.2239470501
#  9.136407498919999 'BERLINO DIR ABBAZIA']
# POINT (1511799.5208113 4341644.36334661)
# ['S107' 'Via Berlino -> Asse Mediano Berlino > Mediano DX' 65 4
#  39.2238952337 9.13644147351 'BERLINO DIR MEDIANO']
# POINT (1511802.4621285 4341638.61729281)
# ['S108' 'Via Berlino -> Asse Mediano Berlino > Mediano SX' 65 4
#  39.2238952337 9.13644147351 'BERLINO DIR MEDIANO']
# POINT (1511802.4621285 4341638.61729281)
# ['S109' 'Via Castiglione -> Via Salvemini Via Castiglione > Salvemini' 68
#  4 39.230031025500004 9.12935841204 'CASTIGLIONE DIR SALVEMINI']
# POINT (1511190.08350064 4342318.65848933)
# ['S110' 'Via Castiglione dir Mediano Via Castiglione > Asse Mediano' 69 4
#  39.2299923721 9.129316474660001 'CASTIGLIONE DIR MEDIANO']
# POINT (1511186.46989103 4342314.36367224)
# ['S111' 'VIa Is Mirrionis -> Via Campania Via Is Mirrionis > Campania DX'
#  59 4 39.2365039304 9.106954173150001 'MIRRIONIS DIR CAMPANIA']
# POINT (1509255.47519706 4343034.49247963)
# ['S112' 'VIa Is Mirrionis -> Via Campania Via Is Mirrionis > Campania SX'
#  59 4 39.2365039304 9.106954173150001 'MIRRIONIS DIR CAMPANIA']
# POINT (1509255.47519706 4343034.49247963)
# ['S113' 'Via Is Mirrionis -> S.Michele Via Is Mirrionis > San Michele DX'
#  60 4 39.2365853415 9.10701256698 'MIRRIONIS DIR S.MICHELE']
# POINT (1509260.5042071 4343043.53323389)
# ['S114' 'Via Is Mirrionis -> S.Michele Via Is Mirrionis > San Michele SX'
#  60 4 39.2365853415 9.10701256698 'MIRRIONIS DIR S.MICHELE']
# POINT (1509260.5042071 4343043.53323389)
# ['S115' 'Via Cornalias -> Via MAttei Via Cornalias > Mattei DX' 73 4
#  39.242269292399996 9.105728244269999 'CORNALIAS DIR METTEI']
# POINT (1509148.92784454 4343674.19605023)
# ['S116' 'Via Cornalias -> Via MAttei Via Cornalias > Mattei SX' 73 4
#  39.242269292399996 9.105728244269999 'CORNALIAS DIR METTEI']
# POINT (1509148.92784454 4343674.19605023)
# ['S117'
#  'Via Cornalias -> P.DellaFrancesca Via Cornalias > P.D.Francesca DX' 74 4
#  39.2422972495 9.10582379781 'CORNALIAS DIR P.D.FRANCESCA']
# POINT (1509157.1702518 4343677.30826671)
# ['S118'
#  'Via Cornalias -> P.DellaFrancesca Via Cornalias > P.D.Francesca SX' 74 4
#  39.2422972495 9.10582379781 'CORNALIAS DIR P.D.FRANCESCA']
# POINT (1509157.1702518 4343677.30826671)
# ['S119' 'Via Is Maglias -> Via Merello Via Is Maglias > Via Merello' 71 4
#  39.2315717405 9.10457030761 'MAGLIAS DIR MERELLO']
# POINT (1509050.36664118 4342486.88989074)
# ['S120' 'Via Is Maglias -> Via Asiago Via Is Maglias > Asiago' 72 4
#  39.231537199899996 9.10453739472 'MAGLIAS DIR ASIAGO']
# POINT (1509047.53032149 4342483.05338823)
# ['S121' 'Viale S.Vincenzo -> Via R.Elena San Vincenzo > Regina Elena' 80 4
#  39.2277638502 9.112496958889999 'SAN VINCENZO DIR R.ELENA']
# POINT (1509735.04277406 4342065.11604562)
# ['S122' 'Viale San Vicenzo -> P.Armi San Vincenzo > Armi' 81 4
#  39.2277284854 9.112470416239999 'SAN VINCENZO DIR ARMI']
# POINT (1509732.75659737 4342061.18850954)
# ['S123' 'Via Vesalio -> Torricelli Via Vesalio > Torricelli DX' 66 4
#  39.238999999499995 9.13163888895 'VESALIO DIR TORRICELLI']
# POINT (1511385.47451753 4343314.2978224)
# ['S124' 'Via Vesalio -> Torricelli Via Vesalio > Torricelli SX' 66 4
#  39.238999999499995 9.13163888895 'VESALIO DIR TORRICELLI']
# POINT (1511385.47451753 4343314.2978224)
# ['S125' 'Via Vesalio -> Via Risorgimento Via Vesalio > Risorgimento DX' 67
#  4 39.2389564172 9.13171214666 'VESALIO DIR RISORGIMENTO']
# POINT (1511391.80377376 4343309.47031793)
# ['S126' 'Via Vesalio -> Via Risorgimento Via Vesalio > Risorgimento SX' 67
#  4 39.2389564172 9.13171214666 'VESALIO DIR RISORGIMENTO']
# POINT (1511391.80377376 4343309.47031793)
# ['S127' 'Via Liguria -> p.Maremma Via Liguria > Maremma DX' 62 4
#  39.2307833502 9.1158388156 'LIGURIA DIR MAREMMA']
# POINT (1510023.0685446 4342400.57535111)
# ['S128' 'Via Liguria -> p.Maremma Via Liguria > Maremma SX' 62 4
#  39.2307833502 9.1158388156 'LIGURIA DIR MAREMMA']
# POINT (1510023.0685446 4342400.57535111)
# ['S129' 'Via Liguria -> Via Campania Via Liguria > Campania SX' 63 4
#  39.2308507872 9.11592587548 'LIGURIA DIR CAMPANIA']
# POINT (1510030.57326317 4342408.06893357)
# ['S130' 'Via Liguria -> Via Campania Via Liguria > Campania DX' 63 4
#  39.2308507872 9.11592587548 'LIGURIA DIR CAMPANIA']
# POINT (1510030.57326317 4342408.06893357)
# ['S131' 'Via Dante altezza Repubblica Via Dante/Repubblica DX' 75 4
#  39.2168063788 9.12488888891 'DANTE/REPUBBLICA']
# POINT (1510806.32524362 4340850.48000982)
# ['S132' 'Via Dante altezza Repubblica Via Dante/Repubblica SX' 75 4
#  39.2168063788 9.12488888891 'DANTE/REPUBBLICA']
# POINT (1510806.32524362 4340850.48000982)
# ['S133' 'Via Del Fangario -> Viale Elmas Via Del Fangario DX' 70 4
#  39.2430277785 9.09591666685 'FANGARIO']
# POINT (1508302.12568933 4343757.43213618)
# ['S134' 'Via Del Fangario -> Viale Elmas Via Del Fangario SX' 70 4
#  39.2430277785 9.09591666685 'FANGARIO']
# POINT (1508302.12568933 4343757.43213618)
# ['S135' 'Viale Trieste -> Avendrace Via Trieste > Avendrace DX' 57 4
#  39.2218611109 9.102444444580001 'TRIESTE DIR AVENDRACE']
# POINT (1508868.09651847 4341409.01879163)
# ['S136' 'Viale Trieste -> Avendrace Via Trieste > Avendrace SX' 57 4
#  39.2218611109 9.102444444580001 'TRIESTE DIR AVENDRACE']
# POINT (1508868.09651847 4341409.01879163)
# ['S137' 'Viale Trieste -> Roma Viale Trieste > Roma SX' 58 4 39.2218413707
#  9.10236813446 'TRIESTE DIR ROMA']
# POINT (1508861.51171376 4341406.82065584)
# ['S138' 'Viale Trieste -> Roma Viale Trieste > Roma DX' 58 4 39.2218413707
#  9.10236813446 'TRIESTE DIR ROMA']
# POINT (1508861.51171376 4341406.82065584)
# ['S139' 'Strada Arginale Strada Arginale DX' 61 4 39.2365345863
#  9.144019641449999 'STRADA ARGINALE']
# POINT (1512454.38472953 4343042.313132)
# ['S140' 'Strada Arginale Strada Arginale SX' 61 4 39.2365345863
#  9.144019641449999 'STRADA ARGINALE']
# POINT (1512454.38472953 4343042.313132)
# ['S141' 'Via Dei Conversi -> Via Tuver Conversi > Tuveri DX' 76 4
#  39.2202963197 9.132401629450001 'CONVERSI DIR TUVERI']
# POINT (1511454.32516074 4341238.70281764)
# ['S142' 'Via Dei Conversi -> Via Tuver Conversi  > Tuveri SX' 76 4
#  39.2202963197 9.132401629450001 'CONVERSI DIR TUVERI']
# POINT (1511454.32516074 4341238.70281764)
# ['S143' 'via dei conversi -> abbazia Conversi > Abbazia' 77 4
#  39.2202247599 9.13242392527 'CONVERSI DIR ABBAZIA']
# POINT (1511456.26140548 4341230.76409572)
# ['S144' 'QSE Leonardo da Vinci -> Via Fiume QUARTU Da Vinci > Fiume' 82 4
#  39.230468 9.222626 'QSE DA VINCI DIR FIUME']
# POINT (1519240.11613 4342382.7586176)
# ['S145'
#  'QSE Leonardo da Vinci -> Via Antas QUARTU Da Vinci > Via Antas DX' 83 4
#  39.230369 9.222555 'QSE DA VINCI DIR ANTAS']
# POINT (1519234.01492818 4342371.75678461)
# ['S146'
#  'QSE Leonardo da Vinci -> Via Antas QUARTU Da Vinci > Via Antas SX' 83 4
#  39.230369 9.222555 'QSE DA VINCI DIR ANTAS']
# POINT (1519234.01492818 4342371.75678461)
# ['S147'
#  'QSE Via Fiume -> Via San Benedetto QUARTU Via Fiume > Via S Benedetto'
#  84 4 39.235959 9.200664999999999 'QSE FIUME DIR S.BENEDETTO']
# POINT (1517343.27260341 4342987.71723035)
# ['S148' 'QSE Via Fiume -> Poetto QUARTU Via Fiume > Poetto' 85 4 39.235875
#  9.200617 'QSE FIUME DIR POETTO']
# POINT (1517339.15056253 4342978.38593099)
# ['S149'
#  'QSE Viale Colombo -> Via Madrid QUARTU Viale Colombo > Via Madrid' 86 4
#  39.229102000000005 9.190641000000001 'QSE COLOMBO DIR MADRID']
# POINT (1516479.74780948 4342224.87749787)
# ['S150' 'QSE Viale Colombo -> Poetto QUARTU Viale Colombo > Poetto' 87 4
#  39.22906 9.190566 'QSE COLOMBO DIR POETTO']
# POINT (1516473.28407675 4342220.20284068)
# ['S151' 'QSE Viale Lungomare -> Cagliari QUARTU Lungomare > Cagliari DX'
#  88 4 39.222867 9.192523 'QSE LUNGOMARE DIR CAGLIARI']
# POINT (1516643.65746629 4341533.2746347)
# ['S152' 'QSE Viale Lungomare -> Cagliari QUARTU Lungomare > Cagliari SX'
#  88 4 39.222867 9.192523 'QSE LUNGOMARE DIR CAGLIARI']
# POINT (1516643.65746629 4341533.2746347)
# ['S153' 'QSE Viale Lungomare -> Quartu QUARTU Lungomare > Quartu DX' 89 4
#  39.222763 9.192573 'QSE LUNGOMARE DIR QUARTU']
# POINT (1516647.99800975 4341521.74211856)
# ['S154' 'QSE Viale Lungomare -> Quartu QUARTU Lungomare > Quartu SX' 89 4
#  39.222763 9.192573 'QSE LUNGOMARE DIR QUARTU']
# POINT (1516647.99800975 4341521.74211856)
# ['S155' 'QSE Via Siena -> Via Zara QUARTU Via Siena > Via Zara' 90 4
#  39.245319 9.1799 'QSE SIENA DIR ZARA']
# POINT (1515549.0867119 4344022.71329531)
# ['S156' 'QSE Via Siena -> Via Br.Sassari QUARTU Siena > Via B.Sassari' 91
#  4 39.245346999999995 9.17985 'QSE SIENA DIR BR.SASSARI']
# POINT (1515544.76586898 4344025.81212771)
# ['S157'
#  'QSE Via Pitz e Serra  > Via Danimarca QUARTU Pitz Serra > Danimarca' 92
#  4 39.240365999999995 9.208662 'QSE PITSERRA DIR DANIMARCA']
# POINT (1518032.33052531 4343478.353486)
# ['S158' "QSE via Pitz'e Serra > via Europa QUARTU Pitz Serra > Europa" 93
#  4 39.240301 9.208664 'QSE PITSERRA DIR EUROPA']
# POINT (1518032.51971396 4343471.14031577)
# ['S159' 'SEL via Roma SELARGIUS Roma > Trieste' 96 4 39.261662 9.174213
#  'SEL VIA ROMA']
# POINT (1515054.85236772 4345835.47197348)
# ['S160' 'SEL via Roma SELARGIUS Roma > del Lavoro' 96 4 39.261662 9.174213
#  'SEL VIA ROMA']
# POINT (1515054.85236772 4345835.47197348)
# ['S161' 'ASS via Carmine ASSEMINI Carmine > Sardegna' 94 4 39.278928
#  9.022822 'ASS CARMINE']
# POINT (1501993.32904626 4347737.46510537)
# ['S162' 'ASS via Carmine ASSEMINI Carmine > Sulcitana' 94 4 39.278928
#  9.022822 'ASS CARMINE']
# POINT (1501993.32904626 4347737.46510537)
# ['S163' 'ASS via Sardegna ASSEMINI Sardegna > Carmine' 95 4 39.290312
#  9.012701 'ASS VIA SARDEGNA']
# POINT (1501120.19622553 4349000.67833211)
# ['S164' 'ASS via Sardegna ASSEMINI Sardegna > SS130' 95 4 39.290312
#  9.012701 'ASS VIA SARDEGNA']
# POINT (1501120.19622553 4349000.67833211)
# ['S165' 'via Cadello > via SM Chiara Cadello > SM Chiara Dx' 97 4
#  39.238911 9.117881 'CADELLO_OUT']
# POINT (1510198.16235011 4343302.79029036)
# ['S166' 'via Cadello > via SM Chiara Cadello > SM Chiara Sx' 97 4
#  39.238911 9.117881 'CADELLO_OUT']
# POINT (1510198.16235011 4343302.79029036)
# ['S167' 'via Cadello > via Is Mirrionis Cadello > Is Mirrionis Sx' 98 4
#  39.238859000000005 9.117545 'CADELLO_IN']
# POINT (1510169.1725124 4343296.98187726)
# ['S168' 'via Cadello > via Is Mirrionis Cadello > Is Mirrionis Dx' 98 4
#  39.238859000000005 9.117545 'CADELLO_IN']
# POINT (1510169.1725124 4343296.98187726)

# %%
con = psy.connect("dbname=testdbgis host=localhost user=postgres password=foobar")
SQL = """
SELECT * 
FROM sensors 
WHERE ST_Contains(ST_GEOMFROMTEXT(%s, 3003), sensors.geom);
"""
RECT = "POLYGON((9.147340 39.239940, 9.147380 39.239940, 9.147380 39.239960, 9.147340 39.239980, 9.147340 39.239940))"

with con:
    with con.cursor() as cur:
        cur.execute(SQL, (map_to_monte_mario(RECT),))
        for x in cur.fetchall():
            print(x)
# Out:
# (1, 'S1', 'Viale Marconi ingresso Viale Marconi ingr dx', 1, 4, '0101000020BB0B000009A39BBF2615374104EDA7879F915041')
# (2, 'S2', 'Viale Marconi ingresso Viale Marconi ingr sx', 1, 4, '0101000020BB0B000009A39BBF2615374104EDA7879F915041')

# %% [markdown]
# ## Saving area-probes location

# %%
con = psy.connect("dbname=testdbgis host=localhost user=postgres password=foobar")

with con:
    with con.cursor() as cur:
        cur.execute("""
            DROP TABLE IF EXISTS areaprobe;
            CREATE TABLE areaprobe (
              id int4 primary key,
              name VARCHAR(20),
              sensor_type int4,
              geom geometry(POLYGON,3003) );
        """)
con.close()

# %%
SQL = """INSERT INTO areaprobe (id, name, geom)
         VALUES (%s, %s, ST_GeomFromText(%s, 3003));"""
RECT = "POLYGON((8.7519483  39.5057942, 8.7519483  38.9511270, 9.4666037  39.5057942,9.4666037  38.9511270, 8.7519483  39.5057942))"


con = psy.connect("dbname=testdbgis host=localhost user=postgres password=foobar")
with con:
    with con.cursor() as cur:
        cur.execute(SQL, (12, 'Radar@UNICA', map_to_monte_mario(RECT)))
con.close()

# %%
con = psy.connect("dbname=testdbgis host=localhost user=postgres password=foobar")
with con:
    with con.cursor() as cur:
        cur.execute("SELECT * from areaprobe")
        for x in cur.fetchall():
            print(x)
con.close()
# Out:
# (12, 'Radar@UNICA', None, '0103000020BB0B000001000000050000000CBF06162B90364191E8EB1C74AE5041CE41864C828F364171627E2D577250414A2BF8A12C803741B9FDF4AF86AE5041C443D66A69813741FCD677AD697250410CBF06162B90364191E8EB1C74AE5041')

# %% [markdown]
# ## Generic geo objects

# %%
con = psy.connect("dbname=testdbgis host=localhost user=postgres password=foobar")

with con:
    with con.cursor() as cur:
        cur.execute("""
            DROP TABLE IF EXISTS geothings;
            CREATE TABLE geothings (
              id int4 primary key,
              name VARCHAR(20),
              type int4,
              geom geometry);
        """)
con.close()

# %%
SQL = """INSERT INTO geothings (id, name, type, geom)
         VALUES (%s, %s, %s, ST_GeomFromText(%s, 3003));"""

con = psy.connect("dbname=testdbgis host=localhost user=postgres password=foobar")
with con:
    with con.cursor() as cur:
        for i, v in zip(sensors.index, sensors.values):
            (name, note, st_id, stype, lat, lon) = v[:-1]
            cur.execute(SQL, (i, name, stype, 
                              map_to_monte_mario("POINT (%s %s)" % (lon, lat))))
            
con.close()

# %%
SQL = """INSERT INTO geothings (id, name, type, geom)
         VALUES (%s, %s, %s, ST_GeomFromText(%s, 3003));"""
RECT = "POLYGON((8.7519483  39.5057942, 8.7519483  38.9511270, 9.4666037  39.5057942,9.4666037  38.9511270, 8.7519483  39.5057942))"

con = psy.connect("dbname=testdbgis host=localhost user=postgres password=foobar")
with con:
    with con.cursor() as cur:
        cur.execute(SQL, (2000, 'Radar@UNICA', 4, map_to_monte_mario(RECT)))
con.close()

# %%
con = psy.connect("dbname=testdbgis host=localhost user=postgres password=foobar")
with con:
    with con.cursor() as cur:
        cur.execute("""
        SELECT name, ST_AsText(ST_Transform(geom,4326)) from geothings
        WHERE ST_DWithin(geom, ST_GeomFromText(%s, 3003), 1000);
        """, (map_to_monte_mario('POINT(9.1092760 39.2284606)'), ))
        for x in cur.fetchall():
            print(x)
con.close()
# Out:
# ('S51', 'POINT(9.12039292999226 39.2286574388301)')
# ('S52', 'POINT(9.12039292999226 39.2286574388301)')
# ('S53', 'POINT(9.12039292999226 39.2286574388301)')
# ('S54', 'POINT(9.12039292999226 39.2286574388301)')
# ('S111', 'POINT(9.10695418035839 39.2365039319305)')
# ('S112', 'POINT(9.10695418035839 39.2365039319305)')
# ('S113', 'POINT(9.10701257418839 39.2365853430306)')
# ('S114', 'POINT(9.10701257418839 39.2365853430306)')
# ('S119', 'POINT(9.10457031481892 39.231571742031)')
# ('S120', 'POINT(9.10453740192893 39.231537201431)')
# ('S121', 'POINT(9.11249696609539 39.2277638517308)')
# ('S122', 'POINT(9.11247042344534 39.2277284869308)')
# ('S127', 'POINT(9.11583882280433 39.2307833517303)')
# ('S128', 'POINT(9.11583882280433 39.2307833517303)')
# ('S129', 'POINT(9.11592588268433 39.2308507887303)')
# ('S130', 'POINT(9.11592588268433 39.2308507887303)')
# ('S135', 'POINT(9.10244445178875 39.2218611124318)')
# ('S136', 'POINT(9.10244445178875 39.2218611124318)')
# ('S137', 'POINT(9.10236814166885 39.2218413722318)')
# ('S138', 'POINT(9.10236814166885 39.2218413722318)')
# ('Radar@UNICA', 'POLYGON((8.75194830737603 39.5057942015357,8.75194830732228 38.9511270015732,9.46660370709149 39.5057942014889,9.46660370703788 38.9511270015269,8.75194830737603 39.5057942015357))')
